# %%
import pickle
model = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/WL_10e_optimise/prod_model_wb0001.pickle", "rb"))
time = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/WL_10e_optimise/time_norm.pickle", "rb"))
flux = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/WL_10e_optimise/white_light_flux.pickle", "rb"))
error = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/WL_10e_optimise/white_light_error.pickle", "rb"))
print(time.shape,flux.shape,error.shape)
# Out:
# (90,) (90,) (90,)

# %%
model.pars
# Out:
# OrderedDict([('t0', <fitting_utils.TransitModelGPPM.Param at 0x15e306fa0>),
#              ('inc', <fitting_utils.TransitModelGPPM.Param at 0x106ed2880>),
#              ('aRs', <fitting_utils.TransitModelGPPM.Param at 0x106ed2a00>),
#              ('period', 4.153658),
#              ('ecc', 0.0),
#              ('omega', 90.0),
#              ('k', <fitting_utils.TransitModelGPPM.Param at 0x10703e070>),
#              ('u1', <fitting_utils.TransitModelGPPM.Param at 0x1682a1040>),
#              ('u2', 0.1453),
#              ('c1', <fitting_utils.TransitModelGPPM.Param at 0x1682a1190>),
#              ('c2', <fitting_utils.TransitModelGPPM.Param at 0x1682a1280>)])

# %%
test = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/initial_WL_fit/rescaled_errors_wb0001.pickle","rb"))
test.shape
# Out:
# (92,)

# %%
print(dir(model))
vars(model)
#model.systematics_model_inputs.shape



model.reducedChisq(time,flux,error)
# Out:
# ['AIC', 'BIC', 'GP_used', '__class__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'ars_fixed', 'batman_model', 'batman_params', 'calc', 'calc_gp_component', 'chisq', 'construct_gp', 'data', 'ecc_fixed', 'exp_ramp_components', 'exp_ramp_used', 'exponential_ramp', 'fix_u1', 'fix_u2', 'inc_fixed', 'kernel_classes', 'kernel_priors', 'ld_law', 'ld_std_priors', 'lnlike', 'lnprior', 'lnprob', 'namelist', 'npars', 'omega_fixed', 'optimise_params', 'pars', 'period_fixed', 'poly_fixed', 'poly_used', 'polynomial_orders', 'red_noise_beta', 'red_noise_poly', 'reducedChisq', 'rms', 'step_func_used', 'step_function', 'systematics_model_inputs', 'time_array', 'u
# ...

# %%
import pickle
flux = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/star1_flux.pickle", "rb"))
flux = flux[0]
import numpy as np
photon_noise = np.sqrt(flux)
relative_photon_noise = photon_noise / flux
flux_err = pickle.load(open("/Users/u2257755/Library/CloudStorage/OneDrive-UniversityofWarwick/LRG_BEASTS/WASP-168/2023-01-25/reduction_2/pickled_objects/star1_error.pickle", "rb"))
flux_err = flux_err[0]

relative_err = flux_err / flux

import matplotlib.pyplot as plt
plt.plot(relative_photon_noise, label="Theoretical photon noise")
plt.plot(relative_err, label="Reported error")
plt.legend()
plt.ylabel("Relative error")
plt.show()
